# %% [markdown]
# <a href="https://colab.research.google.com/github/oache88/SRA268/blob/master/Lab_1_First_Google_Notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Lab 1 - First Google Notebook

# %% [markdown]
# #### Description

# %% [markdown]
# Using the data provided for our first assignment, I wanted to compare the average precipitation percentage for a given day in April and May. I feel like April gets a bad rap for being the 'rainy' month of the year. I feel like May is much more of the rainy month of the year. So I dug a little deeper to prove that April is a superior month than May.
#
# Disclaimer: Owen Ache is born in the Month of April

# %% [markdown]
# #### Graph

# %% [markdown]
# ![alt text](https://raw.githubusercontent.com/oache88/SRA268/master/images/Precipitation%20averages%20of%20the%20Months%20April%20and%20May%202017-2019.png)

# %% [markdown]
# #### Conclusion

# %% [markdown]
# After gathering the data, I believe this all but prooves that April is a superior and less 'rainy' month than May. Each of the last three years, May has had, on average, a higher average precipitation level, per day, than April.  In both 2017 and 2019, May had a higher precipitation average by over 5% than April. I'm sorry for all you April haters, but I think this proves that April is by far the less rainy month compared to May.
